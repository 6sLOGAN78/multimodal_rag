# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from multimodal_rag.ingest import ingest_documents
#       2 from multimodal_rag.config.config import settings
#       3 from multimodal_rag.logger import logger
#
# ModuleNotFoundError: No module named 'multimodal_rag.ingest'
