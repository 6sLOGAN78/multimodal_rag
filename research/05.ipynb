# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser
from langchain.prompts import PromptTemplate

# ✅ Set your Gemini API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyC2C2huU3oN-LQEvIZZCNff4vQhWYtXU5Q"

# Initialize model
model = ChatGoogleGenerativeAI(model="gemini-2.0-flash", google_api_key=os.environ["GOOGLE_API_KEY"])
parser = StrOutputParser()

prompt = PromptTemplate.from_template("Write a haiku about {topic}.")
chain = prompt | model | parser

print(chain.invoke({"topic": "the sunrise"}))
# Out:
# Darkness starts to fade,
# Golden light begins to bloom,
# New day is waking.
